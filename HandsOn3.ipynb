# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashomoulik/DAA-HandsOn-3/blob/main/HandsOn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

#function to calculate the runtime
def f(n):
    x = 1
    for i in range(1, n):
        for j in range(1, n):
            x += 1
    return x

# Time various values of n
n_values = list(range(1,200))  # Testing n from 1 to 200 for timing
times = []

for n in n_values:
    start_time = time.time()
    f(n)
    end_time = time.time()
    times.append(end_time - start_time)

# Plotting time vs n
plt.figure(figsize=(10, 6))
plt.plot(n_values, times, label="Execution Time")
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Time vs n")
plt.grid(True)
plt.show()

# %%
#polynomial fitting
coefficients = np.polyfit(n_values, times, 2)
polynomial = np.poly1d(coefficients)

#generating values
n_fit = np.linspace(min(n_values), max(n_values), 100)
time_fit = polynomial(n_fit)

plt.plot(n_fit, time_fit, '-', label=f'Fit: {coefficients[0]:.2e}n^2 + {coefficients[1]:.2e}n + {coefficients[2]:.2e}')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Fitting polynomial to time data
coeffs = np.polyfit(n_values, times, 2)
poly_fit = np.poly1d(coeffs)

#Generate polynomial to fit line for plotting
fit_times = poly_fit(n_values)
#Plotting original times and the polynomial fit
plt.figure(figsize=(10, 6))
plt.plot(n_values, times, label="Original Times", color='blue')
plt.plot(n_values, fit_times, label=f"Polynomial Fit: {coeffs[0]:.2e}n^2 + {coeffs[1]:.2e}n + {coeffs[2]:.2e}", color='red')
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Time vs n with Polynomial Fit")
plt.legend()
plt.grid(True)
plt.show()

# Showing the polynomial expression
coeffs
# Out:
# array([ 8.77271617e-08,  2.31899265e-06, -2.04002656e-05])

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

#given function
def f(n):
    x = 1
    y = 1
    for i in range(1, n):
        for j in range(1, n):
            x += 1
            y = i+ j
    return x

n_values = list(range(1, 200))
times = []

for n in n_values:
    start_time = time.time()
    f(n)
    end_time = time.time()
    times.append(end_time - start_time)

#Plotting time vs n
plt.figure(figsize=(10, 6))
plt.plot(n_values, times, label="Execution Time")
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Time vs n")
plt.grid(True)
plt.show()

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        Left = arr[:mid]
        Right = arr[mid:]
        merge_sort(Left)
        merge_sort(Right)

        i = j = k = 0
        while i < len(Left) and j < len(Right):
            if Left[i] < Right[j]:
                arr[k] = Left[i]
                i += 1
            else:
                arr[k] = Right[j]
                j += 1
            k += 1

        while i < len(Left):
            arr[k] = Left[i]
            i += 1
            k += 1

        while j < len(Right):
            arr[k] = Right[j]
            j += 1
            k += 1


arr = [5, 2, 4, 7, 1, 3, 2, 6]
merge_sort(arr)
print(arr)
# Out:
# [1, 2, 2, 3, 4, 5, 6, 7]
